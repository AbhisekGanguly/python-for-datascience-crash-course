# %% [markdown]
# # Complete Python for Data Science crash course notebook
# by [*Abhisek Ganguly*](https://abhisekganguly.github.io/official_website)

# %% [markdown]
# ## We are choosing python language for Data Science for various reasons.
# * Easy to learn and implement
# * Open source and high level interpreted language
# * Large community of developers
# * Focuses onproblem solving rather than syntax
# * A huge scientific programming ability with lot of modules to back it up

# %% [markdown]
# ## Let's start by learning about the python interpreter.
# After you've installed python, you can search for the _Python_ in the search-box and find your python interpreter app. The name will be __Python V.x__ , V being your installed python version and x being the release.
#
# You can also open it from the command line (if Python was stored in your user environment at the time of installing), by using the following command in the command prompt `python` or `pythonV.x` (again, V and x are version and release respectively.
#
# ![image.png](attachment:4b16055d-57a7-4ffa-967c-6fe4a4bfb967.png)
# The Python interpreter application
#
# ![image.png](attachment:8061a17a-a418-4b05-92df-e393d4e83fc1.png)
# The python interpreter accessed from windows command prompt
#
# ### This interpreter mode is also known as the Python's Interactive mode

# %% [markdown]
# # Let us now, writer our very first line of code...
# ## The Hello World! program.

# %%
#Printing hello world in Python
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### As you can see, a single line of code, i.e. a print statement alone can show the Hello World output.
# ### Let's see a few more examples of the simple print statement in Python

# %%
print("Hi!, I'm Abhisek.")
# Out:
# Hi!, I'm Abhisek.

# %%
print("I love programming")
# Out:
# I love programming

# %%
#You can also use 'single quote' to write and print in python.
print('This is printed using single quote')
# Out:
# This is printed using single quote

# %%
#If using 'single quotes' then \ can be used to add apostrophe
print('Hi, I\'m Abhisek')
# Out:
# Hi, I'm Abhisek

# %% [markdown]
# ### \n can be used to print a sentence in different lines.

# %%
print('hello \n this is printed in a different line')
# Out:
# hello
#  this is printed in a different line

# %% [markdown]
# ### If you use """triple quotes""" then you can write in multiple lines

# %%
print("""Hello
I'm writing in multiple lines
this is because
I used triple quotes to cover the
sentence""")
# Out:
# Hello
# I'm writing in multiple lines
# this is because
# I used triple quotes to cover the
# sentence
